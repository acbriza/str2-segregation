# %%
import os
import time
import gzip
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Colab\ Notebooks/STR2/segregation
# Out:
# /content/drive/MyDrive/Colab Notebooks/STR2/segregation

# %%
# alpha is for schelling reward
# beta is for vigilance reward
# gamma is for interdependence reward

# parameters: name, iterations, agent_range, prey_reward, max_age, alpha, beta, gamma

# %% [markdown]
# ## Batch Running of Experiments

# %%
# parameters: name, iterations, agent_range, prey_reward, max_age, alpha, beta, gamma

# %%
batch_start_time = time.time()
alphas = [1]
irs = [75]#0, 25, 50, 75, 100
runs = [10] #8, 9, #simulation run numbers
for alpha in alphas:
  for ir in irs:
    for run in runs:
      experiment_start_time = time.time()
      name = f'exp_a{int(alpha*100):03}_ir{ir:03}_r{run:02}'
      cmd = f'python schelling_example.py {name} 5000 5 {ir} 100 {alpha} 1 1'
      print(cmd)
      os.system(cmd)
      seconds = round(time.time() - experiment_start_time)
      print(f"   Experiment duration: {seconds/60:.2f} minutes")    

seconds = round(time.time() - batch_start_time)
num_experiments = len(alphas)*len(irs)*len(runs)
print(f'Finished {num_experiments} experiments.')
print(f"Batch Experiment duration: {seconds/60:.2f} minutes")
# Out:
# python schelling_example.py exp_a100_ir075_r10 5000 5 75 100 1 1 1
#    Experiment duration: 31.75 minutes
# Finished 1 experiments.
# Batch Experiment duration: 31.75 minutes

# %%
#exp_a100_ir075_r10

# %% [markdown]
# python schelling_example.py exp_a100_ir000_r08 5000 5 0 100 1 1 1
#    Experiment duration: 33.40 minutes
# python schelling_example.py exp_a100_ir000_r09 5000 5 0 100 1 1 1
#    Experiment duration: 35.88 minutes
# python schelling_example.py exp_a100_ir000_r10 5000 5 0 100 1 1 1
#    Experiment duration: 36.95 minutes
# python schelling_example.py exp_a100_ir025_r08 5000 5 25 100 1 1 1
#    Experiment duration: 35.98 minutes
# python schelling_example.py exp_a100_ir025_r09 5000 5 25 100 1 1 1
#    Experiment duration: 36.10 minutes
# python schelling_example.py exp_a100_ir025_r10 5000 5 25 100 1 1 1
#    Experiment duration: 36.23 minutes
# python schelling_example.py exp_a100_ir050_r08 5000 5 50 100 1 1 1
#    Experiment duration: 35.52 minutes
# python schelling_example.py exp_a100_ir050_r09 5000 5 50 100 1 1 1
#    Experiment duration: 35.27 minutes
# python schelling_example.py exp_a100_ir050_r10 5000 5 50 100 1 1 1
#    Experiment duration: 35.45 minutes
# python schelling_example.py exp_a100_ir075_r08 5000 5 75 100 1 1 1
#    Experiment duration: 36.05 minutes
# python schelling_example.py exp_a100_ir075_r09 5000 5 75 100 1 1 1
#    Experiment duration: 36.35 minutes
# python schelling_example.py exp_a100_ir075_r10 5000 5 75 100 1 1 1
# ---
# python schelling_example.py exp_a100_ir100_r08 5000 5 100 100 1 1 1
#    Experiment duration: 32.57 minutes
# python schelling_example.py exp_a100_ir100_r09 5000 5 100 100 1 1 1
#    Experiment duration: 39.00 minutes
# python schelling_example.py exp_a100_ir100_r10 5000 5 100 100 1 1 1
#    Experiment duration: 35.72 minutes
# Finished 3 experiments.
# Batch Experiment duration: 107.28 minutes
